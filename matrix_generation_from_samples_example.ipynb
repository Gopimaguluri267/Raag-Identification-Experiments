# %%
import os
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import librosa
import librosa.display
from matplotlib import image


class mfcc_data:
    def mfcc(self, x):
        samples, sampling_rate = librosa.load(x)
        mel = librosa.feature.melspectrogram(samples, sr=sampling_rate, n_mels=128)
        log_mel = librosa.power_to_db(mel, ref=np.max)
        mfcc = librosa.feature.mfcc(S=log_mel, n_mfcc=13)
        delta2_mfcc = librosa.feature.delta(mfcc, order=2)
        return delta2_mfcc

    def mfcc_matrix(self, delta2_mfcc, y):
        plt.figure(figsize=(14,8))
        librosa.display.specshow(delta2_mfcc)
        t='.jpg'
        n = (y[:-4])+t
        plt.savefig(n)
        img = plt.imread(n)
        return img

# %%
l = os.listdir()
l.remove('.ipynb_checkpoints')
l.remove('Untitled.ipynb')

l
# k=l[:3]
# k
# Out:
# ['anandabhairavi__Ambikaye_Arul_Purivaai_1.wav',
#  'anandabhairavi__Ambikaye_Arul_Purivaai_10.wav',
#  'anandabhairavi__Ambikaye_Arul_Purivaai_11.wav',
#  'anandabhairavi__Ambikaye_Arul_Purivaai_12.wav',
#  'anandabhairavi__Ambikaye_Arul_Purivaai_13.wav',
#  'anandabhairavi__Ambikaye_Arul_Purivaai_14.wav',
#  'anandabhairavi__Ambikaye_Arul_Purivaai_15.wav',
#  'anandabhairavi__Ambikaye_Arul_Purivaai_2.wav',
#  'anandabhairavi__Ambikaye_Arul_Purivaai_3.wav',
#  'anandabhairavi__Ambikaye_Arul_Purivaai_4.wav',
#  'anandabhairavi__Ambikaye_Arul_Purivaai_5.wav',
#  'anandabhairavi__Ambikaye_Arul_Purivaai_6.wav',
#  'anandabhairavi__Ambikaye_Arul_Purivaai_7.wav',
#  'anandabhairavi__Ambikaye_Arul_Purivaai_8.wav',
#  'anandabhairavi__Ambikaye_Arul_Purivaai_9.wav',
#  'anandabhairavi__O_Jagadamba_1.wav',
#  'anandabhairavi__O_Jagadamba_10.wav',
#  'anandabhairavi__O_Jagadamba_11.wav',
#  'anandabhairavi__O_Jagadamba_12.wav',
#  'anandabhairavi__O_Jagadamba_13.wav',
#  'anandabhairavi__O_Jagadamba_14.wav',
#  'anandabhairavi__O_Jagadamba_15.wav',
#  'anandabhairavi__O_Jagadamba_2.wav',
#  'anandabhairavi__O_Jagadamba_3.wav',
#  'anandabhairavi__O_Jagadamba_4.wav',
#  'anandabhairavi__O_Jagadamba_5.wav',
#  'anandabhairavi__O_Jagadamba_6.wav',
#  'anandabhairavi__O_Jagadamba_7.wav',
#  'anandabhairavi__O_Jagadamba_8.wav',
#  'anandabhairavi__O_Jagadamba_9.wav']

# %%
r = 'anandabhairavi'
p='_MFCC_imagedata_'
n=str(len(l))
g=r+p+n
e = []

df = pd.DataFrame()
mfd = mfcc_data()
print(g)
# Out:
# anandabhairavi_MFCC_imagedata_30

# %%
for i in l:
    deltas = mfd.mfcc(i)
    imd = mfd.mfcc_matrix(deltas, i)
    d=np.array([imd, r])
    e.append(d)


f = np.array(e)
np.save(g, f)
# Out:
# <ipython-input-1-c3a128490c57>:20: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(14,8))

# %%
# g
# Out:
# 'anandabhairavi_MFCC_imagedata_30'

# %%
# dataset = np.load('anandabhairavi_MFCC_imagedata_30.npy', allow_pickle=True)

# %%
# h=dataset[4][0]

# %%
# plt.imshow(h)
# plt.show()
